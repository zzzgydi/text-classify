# %%
## 简单的示例

import faiss
import numpy as np
d = 64                           # dimension
nb = 100000                      # database size
nq = 10000                       # nb of queries
np.random.seed(1234)             # make reproducible
xb = np.random.random((nb, d)).astype('float32')
xb[:, 0] += np.arange(nb) / 1000.
xq = np.random.random((nq, d)).astype('float32')
xq[:, 0] += np.arange(nq) / 1000.

index = faiss.IndexFlatL2(d)   # build the index
print(index.is_trained)
index.add(xb)                  # add vectors to the index
print(index.ntotal)

xb
# Out:
# True
# 100000
# array([[1.91519454e-01, 6.22108757e-01, 4.37727749e-01, ...,
#         6.24916732e-01, 4.78093803e-01, 1.95675179e-01],
#        [3.83317441e-01, 5.38736843e-02, 4.51648414e-01, ...,
#         1.51395261e-01, 3.35174650e-01, 6.57551765e-01],
#        [7.53425434e-02, 5.50063960e-02, 3.23194802e-01, ...,
#         3.44416976e-01, 6.40880406e-01, 1.26205325e-01],
#        ...,
#        [1.00811470e+02, 5.90245306e-01, 7.98893511e-01, ...,
#         3.39859009e-01, 3.01949501e-01, 8.53854537e-01],
#        [1.00669464e+02, 9.16068792e-01, 9.55078781e-01, ...,
#         5.95364332e-01, 3.84918079e-02, 1.05637990e-01],
#        [1.00855637e+02, 5.91134131e-01, 6.78907931e-01, ...,
#         2.18976989e-01, 6.53015897e-02, 2.17538327e-01]], dtype=float32)

# %%
# 数据处理
from sentence_transformers import SentenceTransformer
import pandas as pd
import faiss

model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# 基础数据
base_data = pd.read_csv('../data/trainset.csv', sep=';')['sentence']
base_embeddings = model.encode(base_data)

# 构造faiss索引
index = faiss.IndexFlatL2(base_embeddings.shape[1])
index.add(base_embeddings)

# 输入要搜索的句子列表，返回对应的相似的句子以及距离
def search_similar(search_data):
    search_embeddings = model.encode(search_data)
    D, I = index.search(search_embeddings, 1)
    distances = [d[0] for d in D]
    sentences = [base_data[i[0]] for i in I]
    results = list(zip(search_data, sentences, distances))
    return results

# %%
query_str_list = ['上海去武汉的航班', '我想订8月15晚上北京飞合肥的机票']

for query_str, result_str, sim in search_similar(query_str_list):
    print('==' * 20)
    print('原句子: ' + query_str)
    print('相似句: ' + result_str)
    print('相似度: ' + str(sim))
# Out:
# ========================================
# 原句子: 上海去武汉的航班
# 相似句: 大连飞往上海的航班
# 相似度: 2.683741
# ========================================
# 原句子: 我想订8月15晚上北京飞合肥的机票
# 相似句: 帮我查一下明天南昌到广州的飞机票
# 相似度: 6.5183682

# %%
# 测试数据
test_data = pd.read_csv('../data/testset.csv', sep=';')['sentence']
test_data = test_data.to_numpy()

np.random.shuffle(test_data)
test_data.size

search_similar(test_data)
# Out:
# [('给我背一首唐诗李白写的', '那你背首唐诗给我听。', 1.8660412),
#  ('发送短消息', '给张克达发短信', 5.145508),
#  ('失明了怎么办？', '近视眼怎么治疗', 13.356136),
#  ('8:10整叫我起床。', '晚上8:10叫我起床。', 1.9688492),
#  ('电焊机用英语怎么说', '庞军军英语怎么说', 9.0571785),
#  ('现在葡萄牙是几点', '海尔滨现在几度！', 19.983147),
#  ('翻译我今天要去打网球', '中超比赛时间，我。', 10.556671),
#  ('电视频道列表', '电视台列表', 2.4029617),
#  ('从南昌到长沙的汽车。', '从中山到西安的汽车。', 2.174038),
#  ('27的立方根的平方', '帮我算一算45的平方根', 6.4923496),
#  ('制作酸梅汤怎么做？', '烧排骨汤需要什么调料？', 3.753069),
#  ('吉林敖东', '甘肃台', 3.5865307),
#  ('安徽的天气', '洛阳的天气', 3.0124187),
#  ('帮我查一下我所在的位置', '讯飞语点我现在在哪里', 2.2655125),
#  ('龙王庙在哪里', '天机富春山居图', 11.282547),
#  ('请打开qq', '上QQ我', 5.298847),
#  ('123和34的积等于多少', '123和34的和等于多少', 2.404705),
#  ('出个脑筋急转弯的。', '啊脑筋急转弯啊', 3.095212),
#  ('45与53的差的倒数', '45与53的差是多少', 2.902008),
#  ('进入当乐网', '赶集网', 1.8993797),
#  ('发短信呢', '发短信', 1.4247055),
#  ('2立方', '2的2次方', 2.1922264),
#  ('chc-动作影院 ', 'chc高清电影昨天晚上的节目', 8.271294),
#  ('灌阳县位置', '广东省英德在哪里', 3.4115057),
#  ('怎么做番茄汤', '红枣鸡汤怎么煲？', 8.591026),
#  ('后天从深圳到成都的航班', '帮我查一下深圳到桂林后天的机票', 3.0240822),
#  ('熊出没啊', '怎么对', 4.0388937),
#  ('我想知道浙江义乌的天气', '洛阳的天气', 3.6316566),
#  ('给肥老发信息', '呼叫广岁', 3.9841719),
#  ('即鱼汤怎么做？', '排骨堡汤的做法。', 6.2849426),
#  ('中央10', '中央十一台', 2.9903069),
#  ('湖南卫视的快乐大本营什么时候播', '我要看湖南卫视快乐大本营', 4.1436977),
#  ('拌面该怎么做？', '甲亢怎么办？', 3.8716908),
#  ('\ufeff春饼哪家好', '南瓜饼的做法。', 8.629211),
#  ('认识俞霖霖吗', '你知道谁是谢志伟吗', 2.4957552),
#  ('播放一首倒带来听一听', '来一首咏柳。', 2.79068),
#  ('福尔摩斯探案集', '查寻科大讯飞的股', 3.5982037),
#  ('肉炒饭怎么做？', '肉肉怎么腌制？', 3.1145515),
#  ('收听安徽广播电台。', '收听中国人民广播电台广播', 3.6634636),
#  ('那你到底是男生还是女生', '你是男生还是女生', 0.67694855),
#  ('烧鸡块怎么做？', '白切鸡怎么做啊？', 3.9317741),
#  ('新建联系人方超幺五五六四二五幺七七七', '新建联系人孙晓飞幺三八三八四四三八九五', 2.9218426),
#  ('哥猜个谜语。', '猜个谜语哦。', 0.4715252),
#  ('给我朗诵一下岳飞的满江红。', '来一首咏柳。', 3.7287407),
#  ('翻译这个多少钱', '多少钱', 10.041035),
#  ('搜索腊梅。', '搜索，西米露的做法。', 2.840005),
#  ('合肥到深圳的火车票', '深圳至合肥的火车票', 0.16283417),
#  ('我想想你刚刚说什么来着', '刚才你说你叫啥来着', 2.6628551),
#  ('来一首白居易的诗了。', '说一句，白居易的诗。', 0.9246731),
#  ('我要点新闻。', '噗我想听新闻。', 2.7039604),
#  ('你在犹豫什么', '你忍心吗', 4.1377287),
#  ('中央三今天有什么节目', '现在中央一台在播什么节目？', 4.370922),
#  ('我要上中学学科网', '我想听求佛。', 5.9627886),
#  ('粉红女郎', '打电话陈雪莉', 11.856945),
#  ('最新有什么热门电影', '那你查一下最近的热门电影是什么？', 2.8889484),
#  ('手癣怎么治疗？', '怎么治疗牛皮癣', 1.7936573),
#  ('下午两点叫醒我。', '晚上8:10叫我起床。', 10.97934),
#  ('孙俪的电视剧', '情景剧电视剧', 4.6024647),
#  ('苹果麦片粥需要哪些材料？', '说话，给我搜一下做苹果麦片粥是怎么做啊？', 7.639244),
#  ('朝阳的天气', '天气桂林', 3.4480991),
#  ('二十五日去深圳的航班', '四月二十日合肥到深圳的航班', 3.6214752),
#  ('见谁', '提是谁', 5.2747917),
#  ('常熟的天气', '天气桂林', 1.2998962),
#  ('给刘俊发短信', '给刘志发短信', 1.0964966),
#  ('安徽卫视今晚放什么节目啊？', '哦，安徽卫视今晚放什么节目？', 0.5799198),
#  ('修改明天和张三去步行街的提醒为去国购', '什么时候和张三去步行街', 4.631078),
#  ('阿勋中集集团的股票', '富瑞特装股票', 3.3220215),
#  ('从东莞到厦门的火车票', '南京到厦门的火车票', 1.8209076),
#  ('4的平方根的立方', '4的平方根', 0.77959824),
#  ('打狗棍播出时间表', '非诚勿扰什么时候演啊', 4.7041235),
#  ('查询东方集团的股票', '查询东吴证券的股票', 1.8859062),
#  ('大西南剿匪记', '查寻科大讯飞的股', 4.860876),
#  ('我说你喜欢我么', '是说我好吗我逗你玩儿', 5.70352),
#  ('热狗了。', '搜狗', 16.116938),
#  ('现在浙江卫视在放什么节目', '河南卫视节目单。', 2.6180372),
#  ('打开优酷视频', '正韵打开相机', 7.5570345),
#  ('背离骚给我听。', '背屈原的离骚', 2.885416),
#  ('来首山口。', '智取威虎山', 2.4512205),
#  ('我想看电影搜索', '我想看搞定岳父大人电影', 4.4580135),
#  ('北京烤鸭做法。', '烤鸭，啊！', 12.1783905),
#  ('查询腾讯股票', '腾讯公司的股票', 2.1388302),
#  ('酒鬼花生怎么做？', '背将进酒。', 6.064501),
#  ('什么地方开会', '哪去', 9.16886),
#  ('电影钢铁侠并论。', '英雄本色电影', 7.130228),
#  ('查一下吉安至武汉的火车', '安阳到郑州的火车', 2.2321625),
#  ('刀削面怎么样做。', '干锅排骨怎么做？', 10.228458),
#  ('为我播报明天的天气', '帮我查一下赣州的天气明天呢', 3.4143715),
#  ('帮我看一下糖醋排骨怎么烧？', '白灼菜心怎么做？', 4.321553),
#  ('8:10提醒我上班。', '提醒我8:10起床。', 9.01244),
#  ('湖南卫视节目录', '今天湖南卫视的电子节目单', 2.098627),
#  ('封神榜', '幻剑书盟', 3.4578857),
#  ('搜索一个字谜了。', '查个字谜。', 1.5356331),
#  ('打开联系人', '开启通讯录', 2.7034826),
#  ('到安徽芜湖怎么走', '去湘江', 2.5876179),
#  ('呼叫晚欲强', '呼叫广岁', 3.3854427),
#  ('做酸菜鱼。', '福寿鱼做法。', 3.5671158),
#  ('一套高清', '甄嬛传高清', 4.160448),
#  ('CCTV4中文国际', 'CCTV6电影高清', 6.784319),
#  ('给陈易云发短消息', '给马翊桐发信息', 2.2205915),
#  ('请帮我调频90.2连云港经济广播电台', '麻烦您可不可以帮我调频98.5扬州人民广播电台新闻台', 3.1856136),
#  ('明天到佛山的航班', '明天去桂林的航班。', 5.9054375),
#  ('今天有什么好的新闻', '看看有什么好新闻', 3.8230858),
#  ('请给我打一个谜语。', '给我讲一个谜语吧！', 1.9560089),
#  ('给茵茵发短信', '给许浩发一条短信', 0.97388077),
#  ('苏泊尔股价大跌', '宏达高科的股票跌了没有', 9.166372),
#  ('红烧鱼怎么烧啊？', '胖鱼头怎么烧？', 5.7117844),
#  ('现在有什么好看的电视剧吗？', '现在有什么好看的电视剧？', 0.5407829),
#  ('你到开心果是什么问题', '汪进祥怎么样', 2.7209845),
#  ('我要订一张到宁波的动车票', '从西安到石嘴山的汽车票。', 5.1263523),
#  ('呼叫琳琳', '打电话陈雪莉', 3.939003),
#  ('我想听最新军事新闻。', '请问一下军事新闻。', 5.161955),
#  ('新水浒传', '幻剑书盟', 2.2703924),
#  ('启动浏览器', '打开uc浏览器', 5.1269703),
#  ('最近有什么大片儿？', '最近有什么好看得', 3.8247128),
#  ('最美好的时光便时计', '最美的时光', 3.8680153),
#  ('没有其他的吗', '不多不要紧都会什么', 4.013241),
#  ('把莫若的电话号码发送给反面教材', '把侨天慧的号码发给副卡', 4.2773876),
#  ('消费者权益日是不是3月15号', '帮我搜一下中超3月份的对阵情况', 9.305251),
#  ('最新电影', '查一查上影电影院即将上映的影片', 4.6818085),
#  ('烧伤怎么治疗啊？', '白灼菜心怎么做？', 9.774858),
#  ('打开搜狐新闻', '打开搜狐微博', 0.9936867),
#  ('我要听昆明新闻。', '打开浦口新闻综合频道', 6.1222744),
#  ('真达林业的股票怎么样', '居然股份股票怎么样', 5.6692142),
#  ('查一下台湾天气', '查看武汉天气', 8.702431),
#  ('电视回看安徽卫视', '收看安徽卫视节目。', 3.4033222),
#  ('查询上海到北京的航班。', '查询上海到玉林的航班。', 2.2879982),
#  ('脊髓损伤。', '如何治疗颈椎病。', 14.588551),
#  ('财经频道今天有什么节目', '现在电视台在放什么节目', 6.375223),
#  ('2012年的恐怖电影', '美国恐怖电影', 4.998621),
#  ('从这里去瑞金路怎么走', '怎么去龙阳路', 1.9052286),
#  ('来一首李白的诗。', '哪里香我来一首李白的诗。', 1.1603909),
#  ('打电话给斌少', '拨打电话给庄开森', 1.2896214),
#  ('几点了', '什么时候去', 5.250452),
#  ('亚洲能源物流股票', '通宝能源股票', 11.048563),
#  ('b股的股票呢', '中信证券股票', 2.892088),
#  ('我想订8月15晚上北京飞合肥的机票', '帮我查一下明天南昌到广州的飞机票', 6.5183754),
#  ('你和Siri是好朋友吗', '你认识siri吗', 9.900799),
#  ('帮我买两注双色球', '上一期双色球开什么', 5.6502705),
#  ('打开我的网易', '开启雅虎', 2.5345917),
#  ('播放搞笑动漫', '搞笑的鬼片', 2.101019),
#  ('打开qq浏览器', '启动qq浏览器', 3.6397133),
#  ('导航到望江西路上去', '导航去科大讯飞', 2.4113083),
#  ('发短信给万若里说你是个傻逼', '你会骂人么', 4.2337065),
#  ('给徐茶叶发短信', '给庄小雷发短信', 1.6360645),
#  ('腰花可以怎么做？', '王志排骨怎么做', 3.0467606),
#  ('梅菜扣肉怎么做啊？', '肉肉怎么腌制？', 3.4563255),
#  ('朗诵李白的静夜思。', '请背诵静夜思。', 2.8329182),
#  ('昨天恒大比赛结果是什么？', '恒大山东鲁能比分是多少？', 8.067516),
#  ('炖鸡', '怎么做炸鸡', 4.199669),
#  ('公交查询', '新浪汽车', 10.111077),
#  ('共同关注', '播放眼色', 4.631648),
#  ('添加一条通讯录姓名张守刚号码是13811725158', '添加一条通讯录姓名葛勇手机号码189571642496', 2.6953697),
#  ('调频fm九十九点二', '调频fm九十七点一', 1.0753574),
#  ('我找男朋友了家里人不同意怎么办', '室友秀恩爱怎么办', 7.7827053),
#  ('冰激凌怎么做哦', '怎么做冰激凌？', 3.0102882),
#  ('把千哥的电话号码发给萌萌', '拨号曹兴发', 3.2934208),
#  ('进入手机qq', '打开手机QQ恩', 2.5830345),
#  ('北京生活频道节目单', '今天湖南卫视的电子节目单', 5.6578484),
#  ('给我来首诗。', '帮我找首诗。', 1.1236267),
#  ('鱼香茄子怎么做', '鱼香肉丝肉怎么做？', 5.0774574),
#  ('小时候住过哪里', '啥时候长大啊', 7.924881),
#  ('哦来一首传奇', '何超盈是谁', 5.7139845),
#  ('看毛泽东在武汉的故事', '康熙大帝', 7.3735905),
#  ('请问酸辣土豆丝是怎么炒的', '土豆丝是怎么炒？', 3.350769),
#  ('放鱼怎么做？', '做鱼怎么做？', 2.279747),
#  ('青鱼做法视频', '昌鱼的做法', 6.2797527),
#  ('来一首毛泽东的词。', '再来背一首毛泽东的诗词。', 3.284565),
#  ('导航到石化小学', '华晶小学在哪里', 5.711563),
#  ('打电话给吴荣因', '拨打电话给庄开森', 0.71365356),
#  ('给李占峰发短信你现在在做什么', '给晓琴发短信你在干吗', 3.5388584),
#  ('打开中关村在线网', '打开丰顺县政府网', 2.7663717),
#  ('搜索东方卫视的电视节目。', '收看安徽卫视节目。', 5.8983746),
#  ('电视上播放什么节目', '电视台在播什么节目', 1.3594875),
#  ('呼叫老公', '打电话给大培', 5.2458076),
#  ('发邮件', '转发这条mail', 2.114542),
#  ('布丁需要哪些材料？', '坐宫保鸡丁需要哪些材料？', 3.595213),
#  ('十分钟以后叫我。', '十分钟后叫我起床。', 6.700989),
#  ('找河南卫视', '苏宁易购', 1.9703255),
#  ('35的平方根', '4的平方根', 4.110298),
#  ('面条怎么样煮啊？', '怎么煮面才好吃呢？', 5.6009636),
#  ('科幻篇', '播放神话', 6.088665),
#  ('牛肉怎么烧', '如何煮牛肉饭。', 5.7853355),
#  ('泰国的节目', '安徽综艺', 7.919571),
#  ('辛夷坞原来你还在这里小说', '地心历险记二', 4.958232),
#  ('查一下新闻。', '听听新闻。', 2.3543358),
#  ('常州在哪', '广东省英德在哪里', 4.644745),
#  ('艺锅肉怎么做？', '罐焖牛肉怎么做？', 3.4018173),
#  ('台剧', '情景剧电视剧', 3.7129421),
#  ('怎样做肉类？', '肉肉怎么腌制？', 2.409649),
#  ('打电话给一十一', '给幺零零幺零打电话', 5.1126404),
#  ('打电话零八', '给幺零零幺零打电话', 2.9824142),
#  ('黔轮胎的走势如何', '播放，青岛中能的赛程。', 8.488569),
#  ('哦，今日头条新闻。', '总计今天的新闻。', 3.1704788),
#  ('天啊是谁', '提是谁', 2.5100517),
#  ('天最新新闻。', '来个最新新闻。', 1.0836868),
#  ('株洲天气', '天气桂林', 1.3955116),
#  ('CCTV第一剧场', 'CCTV四套', 9.046974),
#  ('你需要睡觉吗', '你睡午觉吗', 5.5893),
#  ('中超赛事预告，啊！', '中超赛事预告吗？', 1.9290638),
#  ('帮我查一下淮安到石家庄的火车', '安阳到郑州的火车', 2.432333),
#  ('徐良唱的歌', '播放郁可唯的歌', 1.0541792),
#  ('哈哈，吃了水煮鱼怎么做？', '的，酸菜鱼怎么做？怎么？', 5.6129303),
#  ('蓝猫龙骑团', '铁甲威虫', 10.546203),
#  ('虎胆龙威', '铁甲威虫', 4.3214054),
#  ('有油炸酱料怎么做？', '麻辣烫做法。', 5.049143),
#  ('查一下重庆到贵阳的机票。', '搜索武汉到南京的机票', 3.1780357),
#  ('哥哥是谁', '帮我找一首我的好兄弟', 6.8010387),
#  ('你是不是有病呀', '你忍心吗', 9.49445),
#  ('沿途的科大讯飞', '查一下沿途的科大讯飞', 1.186121),
#  ('我想查询上证指数的股票', '我想看一下科大讯飞的股票', 2.971384),
#  ('帮我查一下温州到汉中的汽车。', '从温州到西安的汽车。', 5.7998962),
#  ('距离12点还有多少秒', '还有多少分钟12点', 3.0844364),
#  ('背一下游子。', '背一首春晓', 4.232828),
#  ('你来吗', '你忍心吗', 6.7036266),
#  ('潍坊到北京机票明天的', '明天长沙到上海的航班', 4.605877),
#  ('把吴琪的电话号码发给妈咪', '打电话陈雪莉', 4.5583897),
#  ('来做烧卖。', '铁板烧怎么做？', 7.470049),
#  ('开启邮件', '给我打开mail', 3.685524),
#  ('商丘天气', '天气桂林', 2.0024624),
#  ('打开五五两性网站', '打开三g门户网站', 5.6769733),
#  ('查一下明天青岛飞往上海的飞机都有哪一些都是几点的', '查询明天南阳到上海的航班', 3.881649),
#  ('怎么考好呢', '王志排骨怎么做', 2.6026402),
#  ('从汕头到西安的汽车。', '宁波到岳阳的汽车。', 5.5813503),
#  ('明天去贵阳的火车', '明天去滁州的火车', 2.7259483),
#  ('爸爸去哪几点结束呀', '找找非诚勿扰什么时候结束', 8.19363),
#  ('飞机场怎么走', '去科大讯飞怎么走', 5.204006),
#  ('搜索西红柿的做法。', '怎么炒番茄炒？', 6.9204063),
#  ('艺轩电影院最近上映的电影有哪些', '给我查一下最近在播哪些电影', 5.2869453),
#  ('今天大乐透开什么号啊', '帮我查一下上一期的大乐透', 3.7431622),
#  ('您好帮我查看一下明天的天气', '帮我查一下赣州的天气明天呢', 2.1049232),
#  ('搜一下小说。', '你能搜到小说不？', 2.5221252),
#  ('安徽电视台', '江苏影视', 1.9587803),
#  ('后天北京天气怎么样啊', '告诉我现在北京天气怎么样', 2.4351997),
#  ('你是谁造的', '谁制造的你啊', 1.9091396),
#  ('给我查一下糖尿病如何治疗？', '能山药怎么做？', 13.851619),
#  ('从重庆到武汉的航班', '晋江到武汉的航班', 2.2581215),
#  ('去汽车东站怎么走', '去汽车南站怎么走', 4.9651737),
#  ('喂我想看电影喂', '你好我想看电影', 1.1960373),
#  ('中超的比赛预告。', '中超赛事预告吗？', 1.7878036),
#  ('我想全部答复', '我想全部回应', 0.87690926),
#  ('查询饶雪漫的言情小说', '朗读咏雪', 2.542327),
#  ('查询重庆水务股票', '查询东吴证券的股票', 6.359701),
#  ('中超比分。', '中超比赛，结果。', 5.5725746),
#  ('打电话给谢文豪', '打电话给魏文强', 1.1986027),
#  ('超级战舰电影', '英雄本色电影', 5.3942432),
#  ('搞笑吗', '讲个笑话吗', 4.4131985),
#  ('中国霸王花', '北京财经台', 7.2169247),
#  ('等一下七点半湖南卫视会播出什么节目', '湖南卫视明天播什么节目', 3.7585602),
#  ('买东西翻译成英语', '福尔摩探案急翻译成英文', 9.081109),
#  ('我想看新闻。', '噗我想听新闻。', 2.423048),
#  ('今天温度是多少', '今天啥天气啊', 6.1764603),
#  ('他开酷狗', '搜狗', 12.157515),
#  ('调幅am六百五十一', '调幅am六百二十八', 1.3757038),
#  ('讲个猜谜语的。', '讲个谜语猜一下。', 0.86576843),
#  ('发送短信给黄启超', '给张克达发短信', 2.4614143),
#  ('死肉怎么烧好吃？', '牛肉怎么煮才好吃？你？', 6.324726),
#  ('请帮我调频98.2山东人民广播电台经济台', '请帮我调频97.5湖南人民广播电台文艺台', 1.3807011),
#  ('你确定你能懂我说的是什么么', '你明白什么', 3.6145325),
#  ('我去杨家坪该怎么走', '怎么去龙阳路', 3.271163),
#  ('国画怎样做土豆烧鸡块', '土豆炒肉丝的做法', 7.1511536),
#  ('请帮我接电话', '给我接听电话', 1.6131287),
#  ('完毕用英文怎么说', '一加一用英语怎么说', 1.0941944),
#  ('打电话给黄组织', '打电话给张志国', 7.0957136),
#  ('我想听听钓鱼岛的新闻。', '关于钓鱼岛的新闻进展', 4.3629417),
#  ('汉堡的英语怎么说', '一加一用英语怎么说', 12.322395),
#  ('可以帮我收听安庆新闻综合广播', '能不能帮我接听中广流行网', 4.2437477),
#  ('提醒', '清空提醒', 2.2779999),
#  ('素烩汤。', '排骨堡汤的做法。', 3.5214539),
#  ('教我煮红烧排骨', '教我怎么做红烧肉', 4.581873),
#  ('打电话给陈永聪', '拨打电话给庄开森', 0.78339577),
#  ('科教频道', '浙江电视台', 2.2553673),
#  ('一分钟后提醒。', '来首宋词。', 6.294545),
#  ('腹泻。', '肠易激综合征。', 7.5495434),
#  ('保险，酸辣土豆丝怎么炒？', '土豆丝是怎么炒？', 7.0788746),
#  ('皮冻的做法。', '冷面的做法。', 3.5091133),
#  ('湖州天气', '苍溪的天气', 5.4849777),
#  ('翻译睡觉了', '给梁辉坚发短信', 4.9537287),
#  ('个来一首路灯下的小姑娘。', '我女儿想去哪里', 17.406694),
#  ('淋病怎么治？', '淋病怎么办', 2.7183743),
#  ('把张三的电话发给李四', '拨打张月华的电话', 4.672802),
#  ('最近有什么热播的电视剧。', '现在热门的电视剧是什么', 2.445444),
#  ('武汉理工大学在哪', '南京火车站到南京农业大学', 8.80298),
#  ('午夜凶铃', '来一首夜夜夜', 7.139305),
#  ('篮球赛事预告。', 'NBA比赛时间。', 6.888466),
#  ('发短信给张三的186的号码我今天请他吃饭', '把李文鼎的号码发给谢服全', 5.9326153),
#  ('酸菜鱼怎么烧的？', '胖鱼头怎么烧？', 4.9520855),
#  ('刘禹锡的秋词。', '看看郑晓龙导演的甄嬛传', 3.1093807),
#  ('今天晚上天津卫视放什么年岁月', '周六晚上重庆卫视有转播神探高伦布吗', 4.9812775),
#  ('发短讯给曹建阳', '给马翊桐发信息', 1.7482986),
#  ('帮我查下下周演新闻联播', '最新的新闻播报一下', 5.2440004),
#  ('我要看cctv五', '我想看c c t v 一频道', 7.163229),
#  ('合肥的天气', '洛阳的天气', 2.8847618),
#  ('从东莞去北海的汽车。', '宁波到岳阳的汽车。', 6.3154793),
#  ('我要买电脑的英语怎么说', '一加一用英语怎么说', 10.36001),
#  ('我要看军事武侠小说', '我要看游戏异界小说', 7.2084503),
#  ('打电话给贾青子', '打电话给王宇婕', 3.2549171),
#  ('怎样做糖醋排骨。', '简单的，糖醋排骨怎么做？', 1.9153728),
#  ('有什么下酒菜吗', '火腿肠怎么炒好吃', 4.9382095),
#  ('给熊媛媛打电话', '给吴方婷打电话', 1.35289),
#  ('给我搜个电影', '查找电影', 1.8227749),
#  ('搜索米聊', '查找通讯录', 2.954358),
#  ('怎样做面筋', '王志排骨怎么做', 1.7413864),
#  ('鸡煲啊！', '怎么做炸鸡', 4.0488396),
#  ('这么久在干嘛呢', '长了什么?', 3.8564043),
#  ('不是说你是难道是说我吗', '谁跟你说没对象了', 5.2249193),
#  ('12月9日北京卫视节目单', '今天湖南卫视的电子节目单', 6.453308),
#  ('我想听搜狐新闻', '打开搜狐微博', 2.7625542),
#  ('最近有什么好看的电影？啊？', '最近有什么好看电影了？', 0.24625015),
#  ('云浮在哪里', '特莫文蔚的阴天。', 9.992725),
#  ('我想听回锅肉做法。', '回锅肉做法。', 5.326065),
#  ('天龙八部第二集', '搜索逃学威龙第二部', 4.2831173),
#  ('好评的喜剧电影', '我想看周星驰的喜剧电影喜剧之王', 5.8689404),
#  ('我们一起去玩吧用英文怎么说', '一加一用英语怎么说', 3.1031036),
#  ('鸡蛋怎么做？', '茄子鸡蛋怎么做？', 3.5274925),
#  ('看新闻。', '听听新闻。', 2.0668373),
#  ('帮我搜索一下羊肉面片。', '黑菜扣肉的做法告诉我一下啊！', 8.353755),
#  ('茅屋为秋风所破歌杜甫。', '背一首春晓', 6.792724),
#  ('鸡怎么烧', '怎么做炸鸡', 6.402485),
#  ('四川卫视频道的节目单', '今天湖南卫视的电子节目单', 3.8388987),
#  ('桂林米粉，哦。', '嘉兴粽子。', 5.1400013),
#  ('查询明天天气', '明天的天气', 2.1220856),
#  ('下个月的提醒都有哪些啊', '帮我搜一下中超3月份的对阵情况', 6.386568),
#  ('大家都说我瘦怎么办呀', '那你是不是很苗条呢', 11.236683),
#  ('从武汉到杭州的火车', '从合肥到北京的列车', 1.6631889),
#  ('你不会念唐诗吗？', '那就来一首李白的诗词吗？', 5.222101),
#  ('我想看中央五台', '我要看中央五台', 0.62820244),
#  ('查询郑州到上海的航班。', '查询上海到玉林的航班。', 1.5218697),
#  ('牧童骑黄牛的下一句是什么？', '红烧猪蹄怎么做', 10.498781),
#  ('张绍刚的综艺节目', '欧阳震华的罪案电视剧', 2.6435003),
#  ('读一首古诗给我听吧！', '念个唐诗给我听。', 2.979002),
#  ('合肥影院', '搜索合肥左岸国际电影城。', 5.8904934),
#  ('今晚红烧肉的做法。', '番红烧肉的做法。', 4.1632023),
#  ('查一下从上海到安徽东至县的路线', '查询北京到上海的路线', 4.6873055),
#  ('小孩子有肺炎的治疗方法有哪些？', '怎么治疗牛皮癣', 15.129681),
#  ('我想跟今天的新闻。', '我想听听今天的新闻。', 1.9206352),
#  ('那用什么来形容', '你是什么意思呀', 1.370779),
#  ('来个谜语吧！', '打个谜语吧！', 0.37120247),
#  ('我要写一条邮件', '帮我写个邮件', 1.3138618),
#  ('九月二十号广州飞北京的航班', '九月二十六号从深圳到宁波的航班', 4.444359),
#  ('明天去成都的航班有几趟', '查询一下明天广州到武汉的航班', 4.028496),
#  ('盖竹柏影也前面一句诗是什么？', '那就来一首李白的诗词。', 3.1420898),
#  ('中央一一台有什么节目吗', '现在中央一台在播什么节目？', 2.3822002),
#  ('帮我查一下赣州到厦门的汽车。', '宁波到杭州的汽车', 3.8044147),
#  ('你只管帅哥吗', '你是不是呆萌啊', 4.2453423),
#  ('附近有没有电影院啊？', '附近电影院。', 7.49469),
#  ('打开极品飞车', '打开珠江台', 3.4926786),
#  ('查一下广州到信阳的火车票', '去广州的火车票', 1.5997658),
#  ('去烟台的火车', '我去烟台有高铁吗', 6.0196),
#  ('来一首剑侠情缘', '苏宁易购', 2.4236183),
#  ('来时打来首唐诗绝句。', '来首李白的诗集。', 2.9558),
#  ('那你告诉我最新的热门电影吧。', '最新的热门电影是什么呀？', 2.7320595),
#  ('板栗如何烧？', '干豆角怎么烧？', 5.6880455),
#  ('播放落日批示', '苏宁易购', 3.4382973),
#  ('酱油汁的做法。', '麻辣烫做法。', 4.182892),
#  ('人死原知万事空下一句是什么？', '落花不是无情物的下一句是什么？', 7.47101),
#  ('桃园天气', '天气桂林', 4.5129013),
#  ('有你漂亮么', '你是不是呆萌啊', 5.139717),
#  ('迎宾路在哪', '哪去', 3.3458672),
#  ('下个星期中国足球超级联赛淘汰赛的赛事前瞻', '江苏舜天队这个星期的比赛时间给我找出来', 6.813181),
#  ('chc高清的节目单', 'chc高清电影昨天晚上的节目', 7.849304),
#  ('麻婆豆腐怎么做', '啥婆豆腐的制作方法', 1.9475937),
#  ('45与32相差多少', '45与53的差是多少', 5.786545),
#  ('看最近有什么电影？', '看看最近有什么电影？', 0.15279198),
#  ('抽刀断水水更流的下一句是什么？', '水里有什么', 8.132847),
#  ('十二频道今天有什么节目', '现在哪个频道播放电视剧', 4.317196),
#  ('阑尾炎', '乳腺炎。', 8.183619),
#  ('打开音乐播放器', '音乐播放器', 4.4185314),
#  ('土豆怎么做才好吃？', '土豆粉怎么做？', 4.8920326),
#  ('给我找到今天的新闻。', '帮我搜索一下今天的新闻', 2.3542404),
#  ('现在的准确时间是几点', '时间现在的', 3.8012733),
#  ('查一下今天早上的新闻。', '看一下今天早上新闻。', 0.5649948),
#  ('同是天涯沦落人下一句。', '背屈原的离骚', 3.7467794),
#  ('桂花糕。', '南瓜饼的做法。', 4.137184),
#  ('查看短消息', '讲点新闻', 2.9580097),
#  ('我想吃汉堡包的英文怎么说', '我饿用英文怎么说', 14.375917),
#  ('叶落长安电视剧', '河南卫视节目单。', 3.9878054),
#  ('打开福州新往网', '打开丰顺县政府网', 4.034565),
#  ('中国香港现在是什么时间', '武汉的精确时间是', 10.503662),
#  ('让读一下沁园春雪毛泽东。', '朗读咏雪', 3.9712687),
#  ('帮我搜索三国杀', '帮我找一找龙门飞甲', 6.9601307),
#  ('中国移动通信的英语怎么说', '中国制用英文怎么说', 5.60429),
#  ('查一下杭州到宁波的火车票', '查一下杭州到鹰潭的火车票', 1.0812645),
#  ('帮我搜索一下宜春到长沙的火车', '帮我查一下洛阳到赣州的火车', 3.362175),
#  ('告诉我怎么去', '我问你怎么走', 4.2765903),
#  ('你不来一首涛声依旧，那你。', '哎，你还是没有上下文啊', 5.367076),
#  ('一路向西', '去常州武进路线', 6.4971027),
#  ('火车南京到衡水', '安阳到郑州的火车', 1.3145199),
#  ('给我搜索唐诗。', '念个唐诗给我听。', 3.1891346),
#  ('到贵阳的航班。', '儋州到海口的航班', 2.681572),
#  ('后天新闻', '讲点新闻', 2.871149),
#  ('糯米肉怎么做？', '米粉肉怎么做？', 5.393963),
#  ('来个脑筋急转弯，那你。', '来个脑筋急转弯儿。', 1.8141041),
#  ('你知道你的名字是什么吗', '唉你叫什么名字', 3.6860619),
#  ('打开网址新浪', '进入讯飞官网', 2.8273382),
#  ('高清北京文艺台', '高清深圳台', 4.8138237),
#  ('日本豆腐的做法。', '炒豆腐。', 6.201475),
#  ('背诵悯农。', '正者无敌', 4.9775667),
#  ('地三鲜怎么做？你？', '肉沫茄子，怎么做？', 3.6605434),
#  ('陕西金叶近日的涨幅情况', '湘潭到常德怎么走', 6.8269405),
#  ('杭州到郑州飞机票', '南昌到广州飞机票', 1.5530701),
#  ('周口在哪里', '哪去', 4.148777),
#  ('汉堡。', '新浪汽车', 20.022753),
#  ('美人心计电视连续剧', '情景剧电视剧', 2.401884),
#  ('上海去武汉的航班', '大连飞往上海的航班', 2.6837502),
#  ('酱牛肉怎么做', '罐焖牛肉怎么做？', 2.0644684),
#  ('来一首钟汉良的视觉动物', '播放眼色', 6.0698967),
#  ('小c 你好我想看河北卫视', '帮我调到安徽卫视', 2.860814),
#  ('中国联通的股票涨还是跌', '中国石化的股票是涨还是跌', 2.7118835),
#  ('帮我搜索一下最近有什么电影可看？', '查一下最近有什么电影？', 1.1418266),
#  ('抬头见喜', '开心大冒险', 3.716157),
#  ('图库', '百度百科', 6.5325546),
#  ('用英语怎么讲', '去你的用英文怎么说', 2.1291046),
#  ('有什么好看的电影没有', '好无聊哇有什么好看的电影', 2.597639),
#  ('我想知道明天的天气如何', '明天天气如何', 1.9158249),
#  ('你是帅哥还是美女', '漂亮和丑你是哪个', 4.2540245),
#  ('浙江高清台的节目单', '东方高清台的节目单', 1.581604),
#  ('切换浦口新闻综合频道', '打开浦口新闻综合频道', 1.4263344),
#  ('陈奕迅有什么歌啊', '播放郁可唯的歌', 1.9853096),
#  ('外面天气如何', '天气如何', 1.4306221),
#  ('读一首毛泽东的诗。', '请念一首毛泽东诗词。', 2.8734665),
#  ('打开谷歌wap', '打开百度啊', 6.229019),
#  ('打开九幺五八聊天', '还能聊点啥呢', 4.7074404),
#  ('是和我没话了吗', '是不是只要我说话你就说话', 3.5302238),
#  ('帮我订明天早晨的机票', '明天去蚌埠的车票', 6.1393757),
#  ('魔神战记', '幻剑书盟', 3.4790897),
#  ('那就来个字谜吧！', '打个谜语吧！', 0.848444),
#  ('明天有什么活动用英语怎么讲', '今天是个好日子的英文怎么讲', 5.653759),
#  ('做凉拌青瓜炒肉用哪些材料？', '做红烧肉要哪些材料呀！', 5.1291676),
#  ('查看双色球开奖', '查看大乐透玩法的开奖', 3.8360891),
#  ('贫血怎么治？', '肾虚怎么治疗', 7.193449),
#  ('你可以帮我点歌吗', '给我随便来几首歌', 4.267847),
#  ('怎么做馒头', '馒头怎么做吗？', 0.67941093),
#  ('我要给陈永信息', '给马翊桐发信息', 2.250616),
#  ('我要看现代言情小说', '我要看现代重生小说', 2.9326801),
#  ('请打开网页', '打开搜狐网首页', 2.2176104),
#  ('你会说情话吗', '说说吗', 2.3135986),
#  ('天才碰麻瓜', '来一首咏柳。', 6.252655),
#  ('猜谜语，听了。', '猜个谜语哦。', 1.6622257),
#  ('从北海到东莞的汽车。', '宁波到岳阳的汽车。', 6.1986675),
#  ('你那儿天气怎么样啊？', '天气怎么样', 6.393059),
#  ('打开骏网一卡通', '打开应用漫画', 4.4366074),
#  ('打开今天朝记事本软件', '开启雅虎', 6.855298),
#  ('鲜肉玉米羹怎么做？', '鱼香肉丝肉怎么做？', 7.101284),
#  ('去永康怎么走', '平阳怎么走吗', 1.6137705),
#  ('腊鱼头怎么做？', '酸菜鱼怎么做啊', 1.5907917),
#  ('我要到徐家汇怎么走', '到薛城区怎么走', 2.014676),
#  ('嘿干什么呢', '嘿干嘛呢', 0.22634697),
#  ('万科a股票', '富瑞特装股票', 1.6459656),
#  ('呼叫小惠', '呼叫鹏鹏', 1.1534958),
#  ('科大讯飞股票价格', '查询科大讯飞的股价', 2.049471),
#  ('陈周的电话号码是多少', '把平水相逢的手机号码发给8000', 6.439932),
#  ('背首唐诗来听啊！', '呵呵，背首诗来听。', 2.2243958),
#  ('我想写一个邮件', '帮我写个邮件', 2.4706306),
#  ('羊肉怎么烧？', '肉肉怎么腌制？', 8.239708),
#  ('发短信给张全三移动的号码我今天请他吃法', '把李文鼎的号码发给谢服全', 4.6667156),
#  ('第50000期福彩双色球', '上一期双色球开什么', 5.0988846),
#  ('点击说话的英语怎么写', '一加一用英语怎么说', 5.1966496),
#  ('豆豉鲮鱼油麦菜', '凉拌菜', 2.571577),
#  ('上一期15选5的中奖号码是多少？', '帮我查一下2013年2月8日开奖的15选5中奖号码', 4.2837124),
#  ('4月28号上海到南昌的航班', '四月二十日合肥到深圳的航班', 3.7388306),
#  ('从这里去科大讯飞如何去', '去科大讯飞怎么走', 1.1340866),
#  ('了，鸡蛋怎么做？', '给蛋炒饭怎么做？', 4.7719994),
#  ('你认识么', '你认识吗', 0.10551834),
#  ('播放吸血鬼日记第二季', '查找90年代好评的武侠电影', 14.146713),
#  ('去重庆的机票多少钱。', '南昌到广州飞机票', 9.031609),
#  ('得了灰指甲怎么办呢？', '得了灰指甲怎么办？', 0.07042885),
#  ('帮我查一下江西铜业股票', '安徽合力股票', 4.404152),
#  ('怎样煮酸甜排骨。', '如何做芝麻糊。', 3.8152714),
#  ('烤鸡翅怎么做呀？', '烤鸡翅怎么做？', 0.03907013),
#  ('那金花和她的女婿', '妈妈的花样年华', 6.1736984),
#  ('给李光发短信', '给黄尚君发短信', 1.4757805),
#  ('浪莎的股票', '富瑞特装股票', 1.5443516),
#  ('今天新余到北京的航班', '查询今天成都到北京的航班', 3.5432186),
#  ('最近有哪些电影的资金字。', '查询恒光电影院即将上映的电影', 6.3580017),
#  ('请帮我调频105山东人民广播电台生活频道', '请帮我调频97.5湖南人民广播电台文艺台', 2.2200718),
#  ('需要你帮我推荐一下电影', '我想看搞定岳父大人电影', 4.7583866),
#  ('煮水饺。', '水饺的做法。', 5.110985),
#  ('买一注5月30号开奖的大乐透', '大乐透的开奖情况', 4.1814737),
#  ('来一首歌尔勤县', '打给曾玮文', 2.5591803),
#  ('我要听稻香', '我要听宋词。', 2.016655),
#  ('重庆到无锡的火车票', '上饶到南昌的火车票', 1.3320885),
#  ('买，来一首诗李白的诗。', '那就来一首李白的诗词。', 2.7793808),
#  ('怎样给宝宝做胡萝卜泥。', '说萝卜怎么做？', 15.05862),
#  ('最近下午有什么电影？', '看看最近有什么电影？', 7.383108),
#  ('你可以干什么', '你能干什么啊', 0.20363808),
#  ('播放卡洛斯沙尔阿', '查找桑拿', 2.8967466),
#  ('中国石化的股票', '中国工商银行的股票', 5.6347313),
#  ('小鸡炖蘑菇的做法爸', '松菇鸡汤的做法。', 4.614395),
#  ('给岚岚发短信', '给张倩倩发短信', 0.9530258),
#  ('八月十九号到成都的航班', '西昌到成都的航班', 4.6947327),
#  ('封神太子', '天利', 3.9198732),
#  ('很想看安徽卫视来着', '帮我调到安徽卫视', 2.278329),
#  ('打给我三姐家里的电话', '给万结打电话', 4.079891),
#  ('中央一套昨天的新闻联播', '最新的新闻播报一下', 3.1188412),
#  ('急性胃肠炎。', '肠易激综合征。', 4.1475124),
#  ('查一下南京到上海的火车注意谢谢', '帮我查一下苏州到上海的火车', 1.3817787),
#  ('中超的比赛时间。', '中超比赛时间，我。', 3.3880348),
#  ('2012年美国公告牌音乐大奖颁奖礼', '音乐播放器', 11.463298),
#  ('东方卫视高清频道', '东方高清台的节目单', 2.9920578),
#  ('高血压怎么办吧', '静脉曲张怎么治疗？哦？', 14.838702),
#  ('为什么要矜持', '背屈原的离骚', 3.4780369),
#  ('毛泽东诗词，咏梅。', '再来背一首毛泽东的诗词。', 3.179123),
#  ('十堰至武汉火车票', '厦门到赣州的火车票', 2.160036),
#  ('浙江卫视今晚有中国好声音吗？', '看中国好声音', 4.020525),
#  ('鸡蛋怎么炒最好吃？', '给蛋炒饭怎么做？', 5.538334),
#  ('我想听s h e 的中国话', '听江苏交通广播网', 8.28421),
#  ('温州今天的新闻', '今天温州有什么新闻。', 1.9872284),
#  ('读新闻听。', '听听新闻。', 2.0052986),
#  ('会唱小星星吗', '想唱就唱', 6.3797016),
#  ('怎么做番茄炒蛋？', '如何做西红柿炒蛋。', 1.486496),
#  ('CCTV6电影', 'CCTV少儿', 3.048645),
#  ('男性节育', '歧路兄弟', 7.6874447),
#  ('替我回复邮件', '替我答复这条邮件', 0.37555885),
#  ('白居易的诗词。', '各来一首李白的诗词。', 1.2274866),
#  ('越策越开心这个节目是哪个台播的呀？', '现在哪个台在播放剧情电视剧', 5.1380672),
#  ('如何治疗脚臭。', '类风湿怎么治？', 14.727325),
#  ('翻译我是一只狗', '搜狗', 8.497448),
#  ('最近流行电影。', '最近有什么热门的电影？', 4.624117),
#  ('去肇庆市怎么坐车？', '上海回合肥怎么坐汽车', 3.222601),
#  ('济宁到潍坊的，车。', '长沙到怀化的汽车。', 6.0157413),
#  ('哪个台播出爱情公寓', '搜索电视剧爱情悠悠药草香在哪个频道首播？', 5.029976),
#  ('给我讲一个长篇小说。', '给我讲个长篇小说。', 0.05486679),
#  ('说话的英文怎么写', '去你的用英文怎么说', 2.7255821),
#  ('念一首唐诗给我听。', '念个唐诗给我听。', 0.26875687),
#  ('美国电影少年派的奇幻漂流', '查一查上影电影院即将上映的影片', 8.922064),
#  ('美女啊帮我打开网页', '打开搜狐微博', 3.7017536),
#  ('请问红烧茄子怎么做？', '红烧排骨怎么做？啊？', 3.3875122),
#  ('糖醋藕怎么做？', '糖醋鲤鱼怎么做？而？', 2.927143),
#  ('内痔怎么办？', '包茎怎么办？', 5.4742336),
#  ('我要听个新闻。', '噗我想听新闻。', 0.61823845),
#  ('咸鸡，的制作方法。', '怎么做炸鸡', 2.743307),
#  ('朱泽圻是谁', '万里鹏是谁', 1.5352888),
#  ('后天去南京的火车', '安阳到郑州的火车', 2.4172764),
#  ('唇腭裂。', '介绍一下尖锐湿疣', 6.2307596),
#  ('太阳是不是有下雨吗', '今天有雨吗', 10.665138),
#  ('淮南电视台综合频道节目。', '今天湖南卫视的电子节目单', 3.942646),
#  ('古墓丽影', '幻剑书盟', 3.8585014),
#  ('来首歌吗？', '放首歌给我听吧', 3.1574821),
#  ('我想出去旅游英文怎么说', '我想打你英语怎么说', 4.8859673),
#  ('打开苹果公司的官方网站', '打开苹果香港官方网站', 8.464254),
#  ('糖醋里脊啊，啊', '做糖醋排骨', 3.5717354),
#  ('来首归家。', '宜家', 4.0709095),
#  ('苹果公司股票每股多少钱啊', '截止目前银鸽投资股份的市值是多少', 15.351845),
#  ('国祥', '浙江台', 1.3519068),
#  ('我要看综艺', '我想看搞定岳父大人电影', 4.38249),
#  ('翻译我想去远方', '福尔摩探案急翻译成英文', 7.234535),
#  ('我想听笨这首歌。', '我想听忐忑这首歌打', 4.581995),
#  ('给黄卫国发短信', '给小阳发短信', 0.7521286),
#  ('帮我打开智能三六零的官网', '给我打开百度网', 3.7840939),
#  ('打电话给地瓜', '给张张打电话', 0.9742012),
#  ('给我播放最近好评的电影', '查一查上影电影院即将上映的影片', 4.068677),
#  ('搜索郑州到南阳的火车票', '查看滁州到南京的火车票', 1.7051296),
#  ('目前六零零零六九的市值啥样', '五零零零零五的市值高不高', 4.5225363),
#  ('麻烦帮我查下万达最近播放哪些电影', '给我查一下最近在播哪些电影', 1.0581303),
#  ('光阴', '天利', 2.6807632),
#  ('打开昆明三六零手机网', '听江苏交通广播网', 6.5457325),
#  ('青海卫视频道的节目单', '河南卫视节目单。', 3.8491402),
#  ('我想转发这封邮件', '我想要转发这封邮件', 0.082265854),
#  ('郑州到许昌的火车', '安阳到郑州的火车', 1.145935),
#  ('我要看新闻玩不？', '多想听新闻，哦。', 3.2561893),
#  ('白萝卜汤怎么做？', '红枣鸡汤怎么煲？', 7.359543),
#  ('把上官围的电话发给戴勋', '打电话给张志国', 2.3026896),
#  ('红烧肉要哪些材料了', '做红烧肉要哪些材料呀！', 1.4481812),
#  ('那你男神是谁', '你哪人啊', 7.5448246),
#  ('穷孩子富孩子', '有什么钱', 16.41386),
#  ('我好想听新城知讯台', '讯飞语音我想知道山东省东营市今天的新闻。', 4.9918804),
#  ('查询中信国安的股票', '查询一下讯飞科大今天的股票', 2.0654726),
#  ('你给我推荐个电影', '你好我想看电影', 5.2364826),
#  ('你是哪儿人啊', '你也是什么', 1.62257),
#  ('中央六套', '中央台五套', 3.0287418),
#  ('开www.china.com', '中国新华网打开', 8.926098),
#  ('查询福建电影院的热映电影', '搜索合肥左岸国际电影城。', 5.4646626),
#  ('来一首一生最爱。', '爱我什么', 8.12998),
#  ('导航到江门', '导航去科大讯飞', 2.597539),
#  ('打电话给王大头', '把王世怀的号码发给乔丽君', 5.2776814),
#  ('乳房的英语怎么说', '阴精英语怎么说', 7.2598686),
#  ('搜索大乐透的号码资讯', '查寻标兵的号码', 3.3919191),
#  ('camera360', 'CCTV6电影高清', 12.895802),
#  ('你有多少最爱啊', '那你最爱的人是谁', 3.5091324),
#  ('给张宁打电话', '拨打电话给庄开森', 1.0486507),
#  ('湖南卫视现在在播什么', '今天湖南卫视的电子节目单', 2.9218998),
#  ('大薯条怎么做？', '馒头怎么做吗？', 7.7447224),
#  ('麻辣豆腐怎么做啊？', '啥婆豆腐的制作方法', 5.2375774),
#  ('啤酒鸭怎么做？', '久久鸭怎么做？', 9.420311),
#  ('来一首飞得更高了说完了', '背一首春晓', 4.3486147),
#  ('湖南卫视电视节目表', '湖南卫视娱乐节目。', 2.4922028),
#  ('腐乳肉怎么做？', '罐焖牛肉怎么做？', 5.6307945),
#  ('死亡笔记', '死亡复生', 8.580456),
#  ('NBA热火季前赛的赛程。', '热火NBA季前赛的那个赛程。', 6.2551537),
#  ('我去过陈中宝吗', '王石的事你怎么看', 5.6312666),
#  ('清蒸武昌鱼。', '昌鱼的做法', 1.5887117),
#  ('今天早上8:10叫我起床。', '晚上8:10叫我起床。', 2.5032463),
#  ('是不是笨笨你觉得你笨吗', '你为啥叫笨笨', 1.7791557),
#  ('我要看巴拉小魔仙', '我想看变形金刚哦', 3.7162094),
#  ('央五', '呼叫鹏鹏', 1.5716476),
#  ('有没有九十年代热门的动漫', '90年代林心如演的电视剧', 5.2452183),
#  ('小军儿炖土豆该怎么做？', '恩，红烧土豆怎么做我想学？', 4.822693),
#  ('给我写一封邮件', '帮我写一封邮件', 0.3363037),
#  ('内裤用英语怎么说', '阴精英语怎么说', 5.4907036),
#  ('啊，猜个谜语给我听。', '猜个谜语哦。', 0.89022064),
#  ('打开我的浏览器', '打开uc浏览器', 3.769886),
#  ('回锅肉怎么做啊', '回锅肉做法。', 1.9994202),
#  ('帮我定一张去镇江的动车票', '合肥到芜湖的火车票', 4.887061),
#  ('郎溪频道', '打开珠江台', 6.332299),
#  ('胡歌忘记时间', '现在不是这个时候大好吗我的大还有没有什么时光网', 5.8195314),
#  ('都市言情小说何以笙箫默', '最近好看的小说', 6.9680843),
#  ('查询武汉到茂名的火车', '贵阳至长沙的火车票', 4.5090637),
#  ('你怎么这么猥琐', '哦买噶谁开发的你这么猥琐', 3.6491518),
#  ('读一首古诗给我听。', '读一首古诗。', 2.8413315),
#  ('CCTV-新闻', 'CCTV记录', 4.0155106),
#  ('搜索凤凰古城位置', '帮我查一下合肥市三孝口在哪里', 5.7327213),
#  ('晋江到温州的火车票', '温州到瑞昌的火车', 2.7072601),
#  ('请帮我打开网站', '你帮我打开网站', 1.454401),
#  ('什么时候有泰囧', '非诚勿扰什么时候演啊', 2.496046),
#  ('3的平方除以2的立方的商减去4的平方根加3', '3的平方除以2的立方的商减去4的平方根的立方', 1.3549614),
#  ('电视剧粘豆包', '情景剧电视剧', 3.8985882),
#  ('高清广东台', '高清江苏', 2.2550068),
#  ('打开德州扑克', '查看大乐透玩法的开奖', 15.252792),
#  ('我要听那首最美的时光', '最美的时光', 2.7984486),
#  ('姜堰到南京的火车', '安阳到郑州的火车', 1.2342052),
#  ('中石油今天的股价', '科大讯飞今天的股票', 7.693326),
#  ('你特长是谁', '你哪人啊', 3.4929562),
#  ('嘉禾电影院正在上映的大片', '查一查上影电影院即将上映的影片', 2.7462978),
#  ('安徽省的天气', '天气桂林', 1.2735691),
#  ('给胡克发短信', '给黄杠发短信', 2.4715004),
#  ('发照片，看看你长什么样', '打开相机我想你', 5.7653217),
#  ('来一首水调歌头。', '我想听水墨丹青这首歌', 4.9587193),
#  ('肩关节周围炎', '肩周炎，要怎么治疗。', 3.083229),
#  ('你是不是', '你是不是啥', 3.1309662),
#  ('查询华峰氨纶的股票', '查询濮耐股份的股票', 1.9607906),
#  ('请问牛排怎么做', '烤牛排怎么做？', 3.5838585),
#  ('广州明天天气好吗', '你好请问一下明天广州的天气如何', 2.9955406),
#  ('南京新闻频道', '播新闻，湖南新闻。', 3.7075005),
#  ('明天什么节目啊？', '那中央六台明天演什么节目', 5.84293),
#  ('查宁波到北京的火车票', '到北京的火车班次', 2.0415306),
#  ('做卤菜需要什么材料？', '坐宫保鸡丁需要哪些材料？', 5.159004),
#  ('你如何做螃蟹？', '螃蟹怎么蒸？', 8.307964),
#  ('长大了要干嘛', '啥时候长大啊', 5.0434246),
#  ('我朗诵唐诗。', '背诵一首唐诗', 5.0342274),
#  ('打电话给何健', '打电话给魏文强', 3.6526318),
#  ('再来一首飞得更高。', '唐诗登高。', 6.3427696),
#  ('CCTV-9的节目单', 'CCTV8高清电视剧', 3.0007877),
#  ('神兵小将', '苏宁易购', 3.0983095),
#  ('你是男生还是女生呀', '你是男生还是女生', 0.13126373),
#  ('再猜一个谜语。', '讲个谜语猜一下。', 0.5989189),
#  ('虎林市电影院正在上映的大片', '查一查上影电影院即将上映的影片', 3.7799196),
#  ('找找大乐透的获奖号码', '看看大乐透的得奖号码', 1.0764637),
#  ('糖醋排骨怎么做呢', '做糖醋排骨', 1.321907),
#  ('我想上qq', '我想上qq了', 1.4299774),
#  ('帮我查一下明天广州到长沙的航班', '帮我查一下广州到长沙的航班', 1.1884842),
#  ('陈忠实的爱情小说《白鹿原》', '玄幻小说《武动乾坤》', 0.99176407),
#  ('重庆天气', '郑州天气怎么样', 4.3033066),
#  ('荒野求', '上山居网', 5.67325),
#  ('赵唱一首歌吧', '播放郁可唯的歌', 3.4469967),
#  ('给一欧阳杰发短信说你是傻逼', '给许浩发一条短信', 3.3896198),
#  ('薛山西路怎么走', '春熙路怎么走', 1.1679688),
#  ('来首青花瓷', '哦来一首青花瓷', 1.7359657),
#  ('新建联系人陈旭东电话幺三八零九二九六幺九六', '新建联系人振华奎号码是幺三五零八九四九三幺二', 3.2501736),
#  ('人心无穷烧肉的做法。', '这么装逼', 9.112375),
#  ('动作电影', '高清动作电影', 2.5057411),
#  ('给夏磊发短信', '给张倩倩发短信', 0.6629162),
#  ('明天下雨不', '今天有雨吗', 10.68222),
#  ('打电话麦亚伦', '打电话陈雪莉', 1.6438332),
#  ('前天中央一套的节目单', '河南卫视节目单。', 2.7770414),
#  ('你QQ号吗诗多少', '上QQ我', 8.429949),
#  ('我要听流行歌曲', '我想听歌曲传奇', 3.5966148),
#  ('打电话给陈正成', '给万结打电话', 0.42747593)]
